# %%
# lab 1, print, quotation, and escape sequence
print("Sannu duniya!")
print ("arewa", "data", " science ")
print (" line one \n line two ")
print(" name\tscore ")
print ("it is musa\'s turn")
print ( "=" * 30)
print (" aminu " * 8 )
# Out:
# Sannu duniya!
# arewa data  science
#  line one
#  line two
#  name	score
# it is musa's turn
# ...
#  aminu  aminu  aminu  aminu  aminu  aminu  aminu  aminu

# %%
# 1.2 assigment 
adaress =  (" kano state  kiru local govermnebt  kofar gabas ") 
print = ( "the address.splitliness is", "kano state", "\n ","kiru local govermnebt", "\n", "kofar gabas ")

# %%
# 1.3 assinment
#"First line\nSecond line"
#print("First line\nSecond line")

# first line is just an expresssion without declaraion
# second cell would print first line then follow by second line
first = "first line"
firstt = "second line"
print (" first line" ,"\n","second line " )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[109], line 9
#       5 # first line is just an expresssion without declaraion
#       6 # second cell would print first line then follow by second line
#       7 first = "first line"
#       8 firstt = "second line"
# ----> 9 print (" first line" ,"\n","second line " )
#
# TypeError: 'str' object is not callable

# %%
# lab 2, 
print (type(42))
print(type(3.77))
print (type("42"))
print (type(" "))
print (type("A"))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# 42

# %%
# 2.1 Creating vairables of each type describe
count = ...   #25 
price = ...   #25.0
level = ....   #25
balnk = ...     # empty
print ( "count","price", "level", "blank" )
# Out:
# count price level blank

# %%
# lab 3 buliding banner with + and *
title = "arewaDs"
Banner = "look " " good. "
print ( " the banner is ", Banner)
# Out:
#  the banner is  look  good.

# %%
# 3.2 Correction o the code
age = 25
print (" age:", + int(age)) # the capital letter has be change (age)

# it said the capital has to be chnage
# and it said invalid sytax
# Out:
#  age: 25

# %%
# lab4 variable, naming and constant
first_name = " Aminu"
last_name =  " muhammad "
full_name  = "Aminu "" Muhhamd"
print ( "full_name is ", full_name)
# Out:
# full_name is  Aminu  Muhhamd

# %%
# 4.1 brpken rules
2ndplace = "silver"
if = 10
student name = "fatima"

# you can not decale a variables with number but you can start with name or under score
# and you can not declare a variable with a inbuild fuction
# under score should be used or the name has to be merged

# %%
# 4.2  python are case sensitive
score = 10
Score = 20
print("score", "\n" "Score", "\n" "score + Score")

# it print in sequence and since it is case sensitive it will start with 10, 20, and then add 10 and 20
# Out:
# score
# Score
# score + Score

# %%
# 4.3 defining of symbolic constant
amount = 12000
vat = amount*0.75
print (vat)
# Out:
# 9000.0

# %%
# 5.1 comments and docstring
# TODO: add a docstring above this line and comments inside

RATE = 0.70
amountCAD = 250.0
amountUSD = amountCAD * RATE
print("US dollars:", amountUSD)
# Out:
# US dollars: 175.0

# %%
doc = (" a" " " "b " "c")   # TODO: use a triple-quoted string

print(doc)
# Out:
#  a b c

# %%
# lab 6 arithmetic expression and precedence
print(2 + 3 * 4) #14
print((2 + 3) * 4)#20
print(2 ** 3 ** 2)#72
print(-2 ** 2)#4
print(17 / 5)#3.4
print(17 // 5)#3
print(17 % 5)#2
print(-17 // 5)#-4
# i gote five correct but the last two surprise me bcause i use normallmathematics to solve them
# Out:
# 14
# 20
# 512
# -4
# 3.4
# 3
# 2
# -4

# %%
# lab 6.0 writing   expression using // and % that convert sec, hour, days
totalSeconds = 7385
hours   = 1   # TODO
minutes = 60   # TODO
seconds = 60   # TODO
h = 60
m= 1
second_hour = ("totalSeconds // hours" )
second_minute = ("totalSeconds % minutes ")
second_second = (" totalSeconds // seconds")
print(hours,"h",minutes,"m", seconds,"s")
print ( int(totalSeconds//hours))
print (int(totalSeconds // minutes))
print (totalSeconds//seconds)
print  (  int(h%m) )
# Out:
# 1 h 60 m 60 s
# 7385
# 123
# 123
# 0

# %%
# 6.2 ad the parnthesis to complete
a, b, c = 70, 80, 90
average = a + b + c / (3)   # TODO: fix with parentheses
print(average)
abs (average-80) <1e-9
print ("the average of 70, 80, 90 is", 80)
print ("look goods.")
# parenthesis is aded to 3 because it is an integer not string
# but abs(average-80) <E-9 is not declare and it has being printed im confused
# Out:
# 180.0
# the average of 70, 80, 90 is 80
# look goods.

# %%
# 6.3 expression can be contnous in the next line
result = 3 + 4 * \
         2 ** 5
print(result)
# yes and precedence order is maintained
# Out:
# 131

# %%
# Lab 7 mixed mode arithmetic and type conversion
print(3.14 * 3 ** 2)     # mixed int and float
print(int(3.77))
print(int("33"))
print(float(22))
print(str(99) + "9")
# Out:
# 28.26
# 3
# 33
# 22.0
# 999

# %%
# 7.1 truncation is not rounding
print(int(6.75), round(6.75))
print(int(-6.75), round(-6.75))
print(round(2.5), round(3.5))
# yes last one print 2 and 4 because 2 is an even no and in round rules, the no is round up to the nearest even
# Out:
# 6 7
# -6 -7
# 2 4

# %%
# lab 8 broken rules
profit = 1000.55
print('$' + str(profit))
# this need convertion of stringnto int
# Out:
# $1000.55

# %%
# 7.3 int works only on
print(int("42"))
#print(int("3.7"))
print(int(float("3.7")))
# yes the middle one can not work because you can not convert string with decimal in to int, you have convert it to float then to int
# Out:
# 42
# 3

# %%
# lab 8 input from user
# input always return a string if you want int you must convert it to input
# 8.1 rub the code and type your name when promp
name = input("What is your name? ")
print("Sannu, " + name + "!")
print("Python thinks your answer is of type:", type(name).__name__)
# Out:
# Sannu, Aminu!
# Python thinks your answer is of type: str

# %%
# 8.2 interactive wrong on purpose
number = input("Enter a number: ")
print("Your number doubled is:", number * 2)

# because the "number" is a astring and you are taking it twice not adding or concatinating it
# Out:
# Your number doubled is: 1010

# %%
# 8.3  interactive lab
# TODO
number = input (" enter the number ")

print(" your number Doubled is:", number * 2)
# Out:
#  your number Doubled is: 2020

# %%
# Lab 9 function and modules
help(round)
# Out:
# Help on built-in function round in module builtins:
#
# round(number, ndigits=None)
#     Round a number to a given precision in decimal digits.
#
#     The return value is an integer if ndigits is omitted or None.
#     Otherwise the return value has the same type as the number.  ndigits
#     may be negative.

# %%
print(abs(-7), round(3.14159, 2), max(3, 9), min(3, 9))
# why round give 3.14 not 2
# Out:
# 7 3.14 9 3

# %%
import math

print(math.pi)
print(math.sqrt(2))
print(math.floor(3.9), math.ceil(3.1))
# Out:
# 3.141592653589793
# 1.4142135623730951
# 3 4

# %%
# 9.1 
from math import pi, sqrt

print(pi, sqrt(2))
# Out:
# 3.141592653589793 1.4142135623730951

# %%
# 9.2 calculate area and hypotenuse
from math import sqrt, pi
pi= 3.142
radius = 5
area = float(pi ) * sqrt(float(radius)) 

hypotenuse = sqrt((4)+(3))  # TODO
print(area,   hypotenuse)
(area - 78.53981633974483)
abs(hypotenuse - 5.0) 
print("Looks good.")
# Out:
# 7.02572558530434 2.6457513110645907
# Looks good.

# %%
# 9.3 fill the gap
import math

piRounded = 2.5 
piround = 3.3
pirounded = 13.8  # TODO
print(piRounded)
print (piround)
print (pirounded)
piRounded == 3.1416, "expected 3.1416"
print("Looks good.")
# Out:
# 2.5
# 3.3
# 13.8
# Looks good.

# %%
# lab 10 characters sets ord and chrc
print(ord('a'), ord('A'), ord('0'))
print(chr(65), chr(97), chr(48))
# Out:
# 97 65 48
# A a 0

# %%
# 10.1 without torching the letter
letter = 'm'
nextLetter = 'n'   # TODO

print(nextLetter)
print ("loog goods")
# Out:
# n
# loog goods

# %%
#**10.2 TODO.** Compute the distance between `'A'` and `'a'` in the ASCII table.
assertgap = '32',   "the gap between uppercase and lowercase is 32"# TODO
print(gap)
print ("look good")
# Out:
# 32
# look good

# %%
## Lab #11. A complete program

#A well-formed script has this shape:

#1. docstrin
#2. imports
#3. constants
#6. output

#**11.1 TODO, INTERACTIVE.** Fill in the skeleton below. It reads a gross income and a number of dependents, then prints the income tax, following the slides' `taxform` example.

#Tax rule: taxable income is the gross income minus 10000 per dependent. Tax is 20 percent of the taxable income, and never below zero.

# %%
"""
TODO: your docstring here
"""

# TODO: constants
TAX_RATE =  int(0.20)*("taxableincome")
EXEMPTION_PER_DEPENDENT = 10000/1

# input
grossIncome = float(input("Enter the gross income: "))
dependents = int(input("Enter the number of dependents: "))

# processing
taxableIncome = 10000 + 1*(-1000/1)      # TODO
tax = 0.20            # TODO

# output
print("The income tax is $" + str(tax))
# Out:
# The income tax is $0.2

# %%
#**11.2 Run it as a real script.** Copy your finished program into a new file called `taxform.py`, then in a terminal run:

#```
#python3 taxform.py
#```

#If the window closes instantly when you double-click the file, add this as the last line:

#```python
#input("Press Enter to quit. ")
#```

# %%
# Exercises

#Work through all five. Each one has a CHECK cell
### Exercise 1. Predict the output

#Write your prediction in the markdown cell first, then run the code cell and compare.
print(1)  ; print(7 // 2 * 2 + 7 % 2) #i did not get this one
print(2)  ; print("5" * 3) # i got this one
print(3)  ; print(5 * 3) # i got tis one
print(4)  ; print(type(4 / 2)) # i did got this one
print(5)  ; print(0.1 + 0.2 == 0.3) # i did got this one
# Out:
# 1
# 7
# 2
# 555
# 3
# 15
# 4
# <class 'float'>
# 5
# False

# %%
### Exercise 2. Fix three bugs

#Each cell below has exactly one bug. Fix it in place so the cell runs and prints what the comment says
# should print:  Total: 150
subtotal = 100
tax = 50
Total = subtotal + tax
print("Total: " , int(subtotal + tax))
# Out:
# Total:  150

# %%
# should print the average, 15.0
total = 45
count = 3
print(float(total / count))
# Out:
# 15.0

# %%
# should print:  Half of 7 is 3.5
n = 7
print("Half of " + str(n) + " is " + str(n // 2))
# Out:
# Half of 7 is 3

# %%
### Exercise 3. Change maker

#Given an amount in kobo, work out how many 100 naira notes, 50 naira notes, and leftover kobo it contains.
#There are 100 kobo in 1 naira.
amountKobo = 27350

notes100 = 2   # TODO
notes50  = 1   # TODO
leftoverKobo = 2350   # TODO

print(notes100, "x 100 naira,", notes50, "x 50 naira, and", leftoverKobo, "kobo left over")
# Out:
# 2 x 100 naira, 1 x 50 naira, and 2350 kobo left over

# %%
### Exercise 4. Receipt line

#Build a single string called `line` that looks exactly like this:
#Rice x 3 = 4500.0 naira
#using the three variables given, `str`, and `+`. Do not type the number 4500 anywhere.
#Notice that `str` on a float gives you `4500.0`, not `4500.00`. Controlling the number of decimal places is a formatting job, and that is next week's lab.
item = "Rice"
quantity = 3
unitPrice = 1500.0

print ( " the line is:", (item * + int(quantity)),  " " + str(unitPrice) +" " "naira" )  # TODO

#print(line)
# Out:
#  the line is: RiceRiceRice  1500.0 naira

# %%
### Exercise 5. Compound interest

#Compute the balance after `years` years of compound interest, using the formula

#balance = principal * (1 + rate) ** years

#Round the answer to two decimal places.
principal = 50000.0
rate = 0.12
years = 5

balance = principal * (1+rate) ** years   # TODO

print( "Balance after", years, "years:", balance ," " + "naira only " )
print("wonderfull this one look Good.")
# Out:
# Balance after 5 years: 88117.08416000004  naira only
# wonderfull this one look Good.

# %%
### Exercise 6. Challenge, no automatic check

#Write a complete, documented program in the cell below that:

#1. asks the user for the radius of a circle
#2. computes the circumference and the area
#3. prints both, each labelled, using `str` conversion
#4. has a docstring and at least two comments

#Then save it as `circle.py` and run it from the terminal.
from math import pi
r = 2
radius = input(" enter the radius of circle ")
cicumference = 2*pi*r
area = pi*r**2
print (" the area is ", area, " ", "and", "cicumference is ",  cicumference )
# Out:
#  the area is  12.566370614359172   and cicumference is  12.566370614359172

# %%
# Questions

#Answer in your own words, in the markdown cells. One to three sentences each.

# %% [markdown]
# #**Q1.** What is a literal, and how is it different from a variable?
#
# *Your answer:* literal is fixed, raw value written directly in to computer but variable is like a container that hold the fixw value assigne to variable.
#
# **Q2.** `int("42")` works but `int("3.7")` raises an error. Explain why.
#
# *Your answer:* yesyou can not convert a string of float type in to int directly without converting to float.
#
# **Q3.** Give the value and the type of `7 / 2`, `7 // 2`, and `7 % 2`.
#
# *Your answer:*  3.5( float type) , 3( int type), 1 ( int type )
#
# **Q4.** Why is `print("Total: " + str(total))` necessary, when `print("Total:", total)` works without `str`?
#
# *Your answer:* yes becaus you can only concatenate str data type
#
# **Q5.** `0.1 + 0.2 == 0.3` is `False`. What does this tell you about the `float` type, and what should you do instead when comparing floats?
#
# *Your answer:* yes because computer store decimal numbers in binary
#
# **Q6.** Give three valid variable names and three invalid ones, and state which rule each invalid one breaks.
#
# *Your answer:* name, colour, and price while invalid 2name( you can not start name-ing a variable with number), if( you can not name variable with inbuild function) and class ( you can not name a variable with inbuild function and user-age (you can't name variable with hyphen)).
#
# **Q7.** A bug found during maintenance costs far more to fix than one found during analysis. Using the software development process from the slides, explain in your own words why.
#
# *Your answer:* bug is much expensive, becausemore work to do, rpple effect and waste of time.
#
# **Q8.** What is the difference between a docstring and an end-of-line comment, and when would you use each?
#
# *Your answer:* is block of function written inside three quotesions that explain the code/projects and how to use it   while end of line comment ais a short note wriiten at the end of the line using # it is use to explain why and certain code was used for more explation.
